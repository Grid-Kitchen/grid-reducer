# %% [markdown]
# 📘 Jupyter Notebook: Visualizing and Comparing Power System Graphs with GeoPandas

# %%
# 📦 Section 1: Imports & Setup
from pathlib import Path
import geopandas as gpd
import pandas as pd
from grid_reducer.opendss import OpenDSS
from grid_reducer.network import get_graph_from_circuit
from grid_reducer.plot import graph_to_geo_dataframe
from grid_reducer.smartds import download_s3_folder
from grid_reducer.reducer import OpenDSSModelReducer
from grid_reducer.add_differential_privacy import (
    LowPrivacyConfig,
    MediumPrivacyConfig,
    HighPrivacyConfig,
)

# %%
# ⚡ Section 2: Load and Parse OpenDSS Circuit

# Specify the path to your DSS master file
# Another DSS file to test; examples on how to download this model are at the end of this notebook
# master_dss_path = Path("../tests/extra_data/P12U/scenarios/base_timeseries/opendss/p12uhs0_1247/p12uhs0_1247--p12udt1271/Master.dss")
master_dss_path = Path("../tests/data/smartds/Master.dss")

# Load the circuit object from the OpenDSS model
ckt = OpenDSS(master_dss_path).get_circuit()

# %%
reducer = OpenDSSModelReducer(master_dss_file=master_dss_path)

# %%
reduced_ckt1 = reducer.reduce(transform_coordinate=False, noise_config=None)
# Out:
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🧹 Removed Secondary Assets:                                                                                    │
# │                                                                                                                 │
# │  • Load: 107 removed, aggregated to 107 nodes.                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Number of aggregated lines = 12
# Number of removed lines = 24
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🔗 Merged Primary Edges:                                                                                        │
# │                                                                                                                 │
# │  • Line_LineCode: 12 merged, 24 removed.                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Has 110 switches
# Total Node Reductions: 614  → 204
# Total Edge Reductions: 506  → 203

# %%
reduced_ckt2 = reducer.reduce(transform_coordinate=False, noise_config=LowPrivacyConfig)
# Out:
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🧹 Removed Secondary Assets:                                                                                    │
# │                                                                                                                 │
# │  • Load: 107 removed, aggregated to 107 nodes.                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Number of aggregated lines = 12
# Number of removed lines = 24
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🔗 Merged Primary Edges:                                                                                        │
# │                                                                                                                 │
# │  • Line_LineCode: 12 merged, 24 removed.                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Has 110 switches
# Total Node Reductions: 614  → 204
# Total Edge Reductions: 506  → 203

# %%
reduced_ckt2a = reducer.reduce(transform_coordinate=False, noise_config=HighPrivacyConfig)
# Out:
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🧹 Removed Secondary Assets:                                                                                    │
# │                                                                                                                 │
# │  • Load: 107 removed, aggregated to 107 nodes.                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Number of aggregated lines = 12
# Number of removed lines = 24
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🔗 Merged Primary Edges:                                                                                        │
# │                                                                                                                 │
# │  • Line_LineCode: 12 merged, 24 removed.                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Has 110 switches
# Total Node Reductions: 614  → 204
# Total Edge Reductions: 506  → 203

# %%
reduced_ckt3 = reducer.reduce(transform_coordinate=True, noise_config=None)
# Out:
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🧹 Removed Secondary Assets:                                                                                    │
# │                                                                                                                 │
# │  • Load: 107 removed, aggregated to 107 nodes.                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Number of aggregated lines = 12
# Number of removed lines = 24
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🔗 Merged Primary Edges:                                                                                        │
# │                                                                                                                 │
# │  • Line_LineCode: 12 merged, 24 removed.                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Has 110 switches
# Total Node Reductions: 614  → 204
# Total Edge Reductions: 506  → 203

# %%
reduced_ckt4 = reducer.reduce(transform_coordinate=True, noise_config=LowPrivacyConfig)
# Out:
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🧹 Removed Secondary Assets:                                                                                    │
# │                                                                                                                 │
# │  • Load: 107 removed, aggregated to 107 nodes.                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Number of aggregated lines = 12
# Number of removed lines = 24
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🔗 Merged Primary Edges:                                                                                        │
# │                                                                                                                 │
# │  • Line_LineCode: 12 merged, 24 removed.                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Has 110 switches
# Total Node Reductions: 614  → 204
# Total Edge Reductions: 506  → 203

# %%
# Create a NetworkX graph from the circuit
# graph = get_graph_from_circuit(ckt)
graph1 = get_graph_from_circuit(reduced_ckt1)
graph2 = get_graph_from_circuit(reduced_ckt2)
graph2a = get_graph_from_circuit(reduced_ckt2a)
graph3 = get_graph_from_circuit(reduced_ckt3)
graph4 = get_graph_from_circuit(reduced_ckt4)
graph5 = get_graph_from_circuit(ckt)

# Print basic info
# print(f"Number of nodes: {len(graph.nodes)}")
# print(f"Number of edges: {len(graph.edges)}")

# %%
gdf1 = graph_to_geo_dataframe(graph1)
gdf2 = graph_to_geo_dataframe(graph2)
gdf2a = graph_to_geo_dataframe(graph2a)
# gdf3 = graph_to_geo_dataframe(graph3)
# gdf4 = graph_to_geo_dataframe(graph4)
gdf5 = graph_to_geo_dataframe(graph5)

# %%
# transform_coordinate=False, noise_level="none"
gdf1.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       0.52  7.199558           Line   line__41
# 1        1      1      2       0.07  7.199558           Line   line__22
# 2        2      1      3       1.97  7.199558           Line  line__128
# 3        3      3    119       0.01  7.199558           Line   line__84
# 4        4      4      5       0.05  7.199558           Line  line__118
#
#                                             geometry
# 0  LINESTRING (-122.48087 38.2472, -122.48538 38....
# 1  LINESTRING (-122.51227 38.26007, -122.51293 38...
# 2  LINESTRING (-122.51227 38.26007, -122.5009 38....
# 3  LINESTRING (-122.5009 38.24649, -122.5009 38.2...
# 4  LINESTRING (-122.5391 38.2444, -122.53866 38.2...

# %%
# transform_coordinate=False, noise_level="low"
gdf2.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       0.52  7.199558           Line   line__41
# 1        1      1      2       0.09  7.199558           Line   line__22
# 2        2      1      3       2.03  7.199558           Line  line__128
# 3        3      3    119       0.04  7.199558           Line   line__84
# 4        4      4      5       0.08  7.199558           Line  line__118
#
#                                             geometry
# 0  LINESTRING (-122.48119 38.24686, -122.48551 38...
# 1  LINESTRING (-122.51272 38.26014, -122.51322 38...
# 2  LINESTRING (-122.51272 38.26014, -122.50062 38...
# 3  LINESTRING (-122.50062 38.24645, -122.50077 38...
# 4  LINESTRING (-122.53912 38.2441, -122.53849 38....

# %%
# transform_coordinate=False, noise_level="high"
gdf2a.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       0.48  7.199558           Line   line__41
# 1        1      1      2       0.12  7.199558           Line   line__22
# 2        2      1      3       2.07  7.199558           Line  line__128
# 3        3      3    119       0.16  7.199558           Line   line__84
# 4        4      4      5       0.14  7.199558           Line  line__118
#
#                                             geometry
# 0  LINESTRING (-122.48082 38.24758, -122.48497 38...
# 1  LINESTRING (-122.51009 38.26124, -122.5098 38....
# 2  LINESTRING (-122.51009 38.26124, -122.49989 38...
# 3  LINESTRING (-122.49989 38.24568, -122.50121 38...
# 4  LINESTRING (-122.53818 38.2444, -122.53934 38....

# %%
# Un-reduced circuit
gdf5.head()
# Out:
#    edge_id                    source      target  length_km        kv  \
# 0        0  p12udt1266-p12uhs0_1247x  p12udt1266       0.52  7.199558
# 1        1                p12udt77lv   p12ulv165       0.02  0.120089
# 2        2                p12udt77lv   p12ulv265       0.01  0.120089
# 3        3                p12udt77lv   p12ulv268       0.05  0.120089
# 4        4                p12udt77lv   p12ulv309       0.02  0.120089
#
#   component_type                             name  high_kv  low_kv  kva  \
# 0           Line  l(r:p12udt1266-p12uhs0_1247)_s1      NaN     NaN  NaN
# 1           Line        l(r:p12udt77lv-p12ulv165)      NaN     NaN  NaN
# 2           Line        l(r:p12udt77lv-p12ulv265)      NaN     NaN  NaN
# 3           Line        l(r:p12udt77lv-p12ulv268)      NaN     NaN  NaN
# 4           Line        l(r:p12udt77lv-p12ulv309)      NaN     NaN  NaN
#
#                                             geometry
# 0  LINESTRING (-122.48087 38.2472, -122.48538 38....
# 1  LINESTRING (-122.54487 38.20966, -122.54503 38...
# 2  LINESTRING (-122.54487 38.20966, -122.54478 38...
# 3  LINESTRING (-122.54487 38.20966, -122.54447 38...
# 4  LINESTRING (-122.54487 38.20966, -122.54497 38...

# %%
gdf5["source"] = "Original"
gdf1["source"] = "Reduced"
gdf2["source"] = "LowNoise"

# gdf2a["source"] = "HighNoise"
combined_gdf = pd.concat([gdf1, gdf2], ignore_index=True)

# %%
# Combined map

m = combined_gdf.explore(
    column="source",
    legend=True,
    cmap="Set1",
    style_kwds={
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
)
m.save("combined_map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_114de8bed384fb40fd05191571a44f1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend source&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;source&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e41a1c&#x27;&gt;&lt;/span&gt;LowNoise&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#999999&#x27;&gt;&lt;/span&gt;Reduced&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_114de8bed384fb40fd05191571a44f1c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_114de8bed384fb40fd05191571a44f1c = L.map(
#                 &quot;map_114de8bed384fb40fd05191571a44f1c&quot;,
#                 {
#                     center: [38.23003879329826, -122.51837943554057],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_114de8bed384fb40fd05191571a44f1c);
#
#
#
#
#
#             var tile_layer_213a65c5167c954a873b51dafea0dc12 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_213a65c5167c954a873b51dafea0dc12.addTo(map_114de8bed384fb40fd05191571a44f1c);
#
#
#             map_114de8bed384fb40fd05191571a44f1c.fitBounds(
#                 [[38.19733166011807, -122.55588415901687], [38.26274592647846, -122.48087471206428]],
#                 {}
#             );
#
#
#         function geo_json_7920bfeb3fa76e43d26006dddb03252b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;

# %%
# transform_coordinate=False, noise_level="none"
gdf1.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b5fea66ac6a6b335d549e2839f54fc5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b5fea66ac6a6b335d549e2839f54fc5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b5fea66ac6a6b335d549e2839f54fc5 = L.map(
#                 &quot;map_3b5fea66ac6a6b335d549e2839f54fc5&quot;,
#                 {
#                     center: [38.23003879329826, -122.51837943554057],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_3b5fea66ac6a6b335d549e2839f54fc5);
#
#
#
#
#
#             var tile_layer_e150ece729437119189107b9552f8148 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e150ece729437119189107b9552f8148.addTo(map_3b5fea66ac6a6b335d549e2839f54fc5);
#
#
#             map_3b5fea66ac6a6b335d549e2839f54fc5.fitBounds(
#                 [[38.19733166011807, -122.55588415901687], [38.26274592647846, -122.48087471206428]],
#                 {}
#             );
#
#
#         function geo_json_fc5e7e0e6e8d658a7d388613520604eb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_fc5e7e0e6e8d658a7d388613520604eb_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_fc5e7e0e6e8d658a7d388613520604eb_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_fc5e7e0e6e8d658a7d388613520604eb_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_fc5e7e0e6e8d658a7d388613520604eb_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_fc5e7e0e6e8d658a7d388613520604eb.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_fc5e7e0e6e8d658a7d388613520604eb_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_fc5e7e0e6e8d658a7d388613520604eb = L.geoJson(null, {
#                 onEachFeature: geo_json_fc5e7e0e6e8d658a7d388613520604eb_onEachFeature,
#
#                 style: geo_json_fc5e7e0e6e8d658a7d388613520604eb_styler,
#                 pointToLayer: geo_json_fc5e7e0e6e8d658a7d388613520604eb_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_fc5e7e0e6e8d658a7d388613520604eb_add (data) {
#             geo_json_fc5e7e0e6e8d658a7d388613520604eb
#                 .addData(data);
#         }
#             geo_json_fc5e7e0e6e8d658a7d388613520604eb_add({&quot;bbox&quot;: [-122.55588415901687, 38.19733166011807, -122.48087471206428, 38.26274592647846], &quot;features&quot;: [{&quot;bbox&quot;: [-122.48538151936485, 38.247201582318546, -122.48087471206428, 38.24855675680422], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.48087471206428, 38.247201582318546], [-122.48538151936485, 38.24855675680422]], &quot;type&qu

# %%
# ## Code to download other Smart DS models
# #### Download the profiles for P12U feeder first
# download_s3_folder(
#     "oedi-data-lake", 
#     "SMART-DS/v1.0/2018/SFO/P12U/profiles/", 
#     "../tests/extra_data/P12U/profiles"
# )

# %%
# download_s3_folder(
#     "oedi-data-lake", 
#     "SMART-DS/v1.0/2018/SFO/P12U/scenarios/base_timeseries/opendss/p12uhs0_1247/p12uhs0_1247--p12udt1271/", 
#     "../tests/extra_data/P12U/scenarios/base_timeseries/opendss/p12uhs0_1247/p12uhs0_1247--p12udt1271/"
# )
