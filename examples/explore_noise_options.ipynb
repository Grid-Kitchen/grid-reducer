# %% [markdown]
# 📘 Jupyter Notebook: Visualizing and Comparing Power System Graphs with GeoPandas

# %%
# 📦 Section 1: Imports & Setup
from pathlib import Path
import geopandas as gpd
import pandas as pd
from grid_reducer.opendss import OpenDSS
from grid_reducer.network import get_graph_from_circuit
from grid_reducer.plot import graph_to_geo_dataframe
from grid_reducer.reducer import OpenDSSModelReducer
from grid_reducer.add_differential_privacy import (
    LowPrivacyConfig,
    MediumPrivacyConfig,
    HighPrivacyConfig,
)

# %%
# ⚡ Section 2: Load and Parse OpenDSS Circuit

# Specify the path to your DSS master file
master_dss_path = Path("../tests/data/smartds/Master.dss")

# Load the circuit object from the OpenDSS model
ckt = OpenDSS(master_dss_path).get_circuit()
reducer = OpenDSSModelReducer(master_dss_file=master_dss_path)
reduced_ckt1 = reducer.reduce(transform_coordinate=False, noise_config=None)
reduced_ckt2 = reducer.reduce(transform_coordinate=False, noise_config=LowPrivacyConfig)
reduced_ckt2a = reducer.reduce(transform_coordinate=False, noise_config=HighPrivacyConfig)
reduced_ckt3 = reducer.reduce(transform_coordinate=True, noise_config=None)
reduced_ckt4 = reducer.reduce(transform_coordinate=True, noise_config=LowPrivacyConfig)

# Create a NetworkX graph from the circuit
# graph = get_graph_from_circuit(ckt)
graph1 = get_graph_from_circuit(reduced_ckt1)
graph2 = get_graph_from_circuit(reduced_ckt2)
graph2a = get_graph_from_circuit(reduced_ckt2a)
graph3 = get_graph_from_circuit(reduced_ckt3)
graph4 = get_graph_from_circuit(reduced_ckt4)
graph5 = get_graph_from_circuit(ckt)

# Print basic info
# print(f"Number of nodes: {len(graph.nodes)}")
# print(f"Number of edges: {len(graph.edges)}")
# Out:
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🧹 Removed Secondary Assets:                                                                                    │
# │                                                                                                                 │
# │  • Load: 107 removed, aggregated to 107 nodes.                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Number of aggregated lines = 12
# Number of removed lines = 24
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🔗 Merged Primary Edges:                                                                                        │
# │                                                                                                                 │
# │  • Line_LineCode: 12 merged, 24 removed.                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Total Node Reductions: 614  → 204
# Total Edge Reductions: 506  → 203
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🧹 Removed Secondary Assets:                                                                                    │
# │                                                                                                                 │
# │  • Load: 107 removed, aggregated to 107 nodes.                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Number of aggregated lines = 12
# Number of removed lines = 24
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🔗 Merged Primary Edges:                                                                                        │
# │                                                                                                                 │
# │  • Line_LineCode: 12 merged, 24 removed.                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Noise level:low; Epsilon: 5000
# Total Node Reductions: 614  → 204
# Total Edge Reductions: 506  → 203
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🧹 Removed Secondary Assets:                                                                                    │
# │                                                                                                                 │
# │  • Load: 107 removed, aggregated to 107 nodes.                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Number of aggregated lines = 12
# Number of removed lines = 24
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🔗 Merged Primary Edges:                                                                                        │
# │                                                                                                                 │
# │  • Line_LineCode: 12 merged, 24 removed.                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Noise level:high; Epsilon: 2000
# Total Node Reductions: 614  → 204
# Total Edge Reductions: 506  → 203
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🧹 Removed Secondary Assets:                                                                                    │
# │                                                                                                                 │
# │  • Load: 107 removed, aggregated to 107 nodes.                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Number of aggregated lines = 12
# Number of removed lines = 24
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🔗 Merged Primary Edges:                                                                                        │
# │                                                                                                                 │
# │  • Line_LineCode: 12 merged, 24 removed.                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Transforming coordinates...
# Time: 0.6011848449707031
# Total Node Reductions: 614  → 204
# Total Edge Reductions: 506  → 203
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🧹 Removed Secondary Assets:                                                                                    │
# │                                                                                                                 │
# │  • Load: 107 removed, aggregated to 107 nodes.                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Number of aggregated lines = 12
# Number of removed lines = 24
# ╭─────────────────────────────────────────────── 🧾 Summary Report ───────────────────────────────────────────────╮
# │ 🔗 Merged Primary Edges:                                                                                        │
# │                                                                                                                 │
# │  • Line_LineCode: 12 merged, 24 removed.                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Transforming coordinates...
# Time: 0.24546217918395996
# Noise level:low; Noise scale: 0.01
# Total Node Reductions: 614  → 204
# Total Edge Reductions: 506  → 203

# %%
gdf1 = graph_to_geo_dataframe(graph1)
gdf2 = graph_to_geo_dataframe(graph2)
gdf2a = graph_to_geo_dataframe(graph2a)
gdf3 = graph_to_geo_dataframe(graph3)
gdf4 = graph_to_geo_dataframe(graph4)
gdf5 = graph_to_geo_dataframe(graph5)

# %%
# transform_coordinate=False, noise_level="none"
gdf1.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       0.52  7.199558           Line   line__50
# 1        1      1      2       0.07  7.199558           Line   line__22
# 2        2      1      3       1.97  7.199558           Line  line__128
# 3        3      3    119       0.01  7.199558           Line   line__37
# 4        4      4    123       0.00  7.199558           Line   line__71
#
#                                             geometry
# 0  LINESTRING (-122.48087 38.2472, -122.48538 38....
# 1  LINESTRING (-122.51227 38.26007, -122.51293 38...
# 2  LINESTRING (-122.51227 38.26007, -122.5009 38....
# 3  LINESTRING (-122.5009 38.24649, -122.5009 38.2...
# 4  LINESTRING (-122.5391 38.2444, -122.53911 38.2...

# %%
# transform_coordinate=False, noise_level="low"
gdf2.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       0.50  7.199558           Line   line__50
# 1        1      1      2       0.15  7.199558           Line   line__22
# 2        2      1      3       1.99  7.199558           Line  line__128
# 3        3      3    119       0.10  7.199558           Line   line__37
# 4        4      4    123       0.16  7.199558           Line   line__71
#
#                                             geometry
# 0  LINESTRING (-122.48107 38.24742, -122.48545 38...
# 1  LINESTRING (-122.51208 38.25957, -122.51336 38...
# 2  LINESTRING (-122.51208 38.25957, -122.50008 38...
# 3  LINESTRING (-122.50008 38.24622, -122.50093 38...
# 4  LINESTRING (-122.53839 38.24421, -122.53981 38...

# %%
# transform_coordinate=False, noise_level="high"
gdf2a.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       0.48  7.199558           Line   line__50
# 1        1      1      2       0.17  7.199558           Line   line__22
# 2        2      1      3       1.98  7.199558           Line  line__128
# 3        3      3    119       0.08  7.199558           Line   line__37
# 4        4      4    123       0.16  7.199558           Line   line__71
#
#                                             geometry
# 0  LINESTRING (-122.48109 38.24721, -122.4851 38....
# 1  LINESTRING (-122.51198 38.26014, -122.51332 38...
# 2  LINESTRING (-122.51198 38.26014, -122.50065 38...
# 3  LINESTRING (-122.50065 38.24637, -122.49998 38...
# 4  LINESTRING (-122.53876 38.24443, -122.53745 38...

# %%
# transform_coordinate=True, noise_level="none"
gdf3.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       3.60  7.199558           Line   line__50
# 1        1      1      2       3.59  7.199558           Line   line__22
# 2        2      1      3       3.58  7.199558           Line  line__128
# 3        3      3    119       3.46  7.199558           Line   line__37
# 4        4      4    123       3.68  7.199558           Line   line__71
#
#                                             geometry
# 0    LINESTRING (-0.47362 0.23429, -0.46882 0.20218)
# 1    LINESTRING (-0.40613 0.15445, -0.40286 0.18664)
# 2     LINESTRING (-0.40613 0.15445, -0.4177 0.12435)
# 3     LINESTRING (-0.4177 0.12435, -0.44263 0.10567)
# 4  LINESTRING (-0.62087 -0.39656, -0.59517 -0.37564)

# %%
# transform_coordinate=True, noise_level="low"
gdf4.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       2.82  7.199558           Line   line__50
# 1        1      1      2       5.50  7.199558           Line   line__22
# 2        2      1      3       3.10  7.199558           Line  line__128
# 3        3      3    119       4.49  7.199558           Line   line__37
# 4        4      4    123       4.05  7.199558           Line   line__71
#
#                                             geometry
# 0     LINESTRING (-0.4672 0.23114, -0.46758 0.20573)
# 1       LINESTRING (-0.4035 0.15048, -0.3909 0.1984)
# 2     LINESTRING (-0.4035 0.15048, -0.42083 0.12856)
# 3    LINESTRING (-0.42083 0.12856, -0.45305 0.10415)
# 4  LINESTRING (-0.61839 -0.39375, -0.59067 -0.36999)

# %%
# Un-reduced circuit
gdf5.head()
# Out:
#    edge_id                    source      target  length_km        kv  \
# 0        0  p12udt1266-p12uhs0_1247x  p12udt1266       0.52  7.199558
# 1        1                p12udt77lv   p12ulv165       0.02  0.120089
# 2        2                p12udt77lv   p12ulv265       0.01  0.120089
# 3        3                p12udt77lv   p12ulv268       0.05  0.120089
# 4        4                p12udt77lv   p12ulv309       0.02  0.120089
#
#   component_type                             name  high_kv  low_kv  kva  \
# 0           Line  l(r:p12udt1266-p12uhs0_1247)_s1      NaN     NaN  NaN
# 1           Line        l(r:p12udt77lv-p12ulv165)      NaN     NaN  NaN
# 2           Line        l(r:p12udt77lv-p12ulv265)      NaN     NaN  NaN
# 3           Line        l(r:p12udt77lv-p12ulv268)      NaN     NaN  NaN
# 4           Line        l(r:p12udt77lv-p12ulv309)      NaN     NaN  NaN
#
#                                             geometry
# 0  LINESTRING (-122.48087 38.2472, -122.48538 38....
# 1  LINESTRING (-122.54487 38.20966, -122.54503 38...
# 2  LINESTRING (-122.54487 38.20966, -122.54478 38...
# 3  LINESTRING (-122.54487 38.20966, -122.54447 38...
# 4  LINESTRING (-122.54487 38.20966, -122.54497 38...

# %%
gdf1["source"] = "Base"
gdf2["source"] = "LowNoise"
# gdf2a["source"] = "HighNoise"
combined_gdf = pd.concat([gdf1, gdf2], ignore_index=True)

# %%
# Combined map

m = combined_gdf.explore(
    column="source",
    legend=True,
    cmap="Set1",
    style_kwds={
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
)
m.save("combined_map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18fae7302d4934dc026f89a6b99180b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend source&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;source&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e41a1c&#x27;&gt;&lt;/span&gt;Base&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#999999&#x27;&gt;&lt;/span&gt;LowNoise&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18fae7302d4934dc026f89a6b99180b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18fae7302d4934dc026f89a6b99180b9 = L.map(
#                 &quot;map_18fae7302d4934dc026f89a6b99180b9&quot;,
#                 {
#                     center: [38.22995918058727, -122.51837943554057],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_18fae7302d4934dc026f89a6b99180b9);
#
#
#
#
#
#             var tile_layer_318c20c6ecd77b826bda9c87f2ec264a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_318c20c6ecd77b826bda9c87f2ec264a.addTo(map_18fae7302d4934dc026f89a6b99180b9);
#
#
#             map_18fae7302d4934dc026f89a6b99180b9.fitBounds(
#                 [[38.197172434696085, -122.55588415901687], [38.26274592647846, -122.48087471206428]],
#                 {}
#             );
#
#
#         function geo_json_5bf89b79539731a38fb02308da166758_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;34

# %%
# transform_coordinate=False, noise_level="none"
gdf1.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af1f0c5becf9463fce753af30e562518 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af1f0c5becf9463fce753af30e562518&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af1f0c5becf9463fce753af30e562518 = L.map(
#                 &quot;map_af1f0c5becf9463fce753af30e562518&quot;,
#                 {
#                     center: [38.23003879329826, -122.51837943554057],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_af1f0c5becf9463fce753af30e562518);
#
#
#
#
#
#             var tile_layer_514116b356df8a119d98069fa225103d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_514116b356df8a119d98069fa225103d.addTo(map_af1f0c5becf9463fce753af30e562518);
#
#
#             map_af1f0c5becf9463fce753af30e562518.fitBounds(
#                 [[38.19733166011807, -122.55588415901687], [38.26274592647846, -122.48087471206428]],
#                 {}
#             );
#
#
#         function geo_json_bf0907b1afacdb98daa44025acee92c0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_bf0907b1afacdb98daa44025acee92c0_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_bf0907b1afacdb98daa44025acee92c0_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_bf0907b1afacdb98daa44025acee92c0_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_bf0907b1afacdb98daa44025acee92c0_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_bf0907b1afacdb98daa44025acee92c0.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_bf0907b1afacdb98daa44025acee92c0_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_bf0907b1afacdb98daa44025acee92c0 = L.geoJson(null, {
#                 onEachFeature: geo_json_bf0907b1afacdb98daa44025acee92c0_onEachFeature,
#
#                 style: geo_json_bf0907b1afacdb98daa44025acee92c0_styler,
#                 pointToLayer: geo_json_bf0907b1afacdb98daa44025acee92c0_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_bf0907b1afacdb98daa44025acee92c0_add (data) {
#             geo_json_bf0907b1afacdb98daa44025acee92c0
#                 .addData(data);
#         }
#             geo_json_bf0907b1afacdb98daa44025acee92c0_add({&quot;bbox&quot;: [-122.55588415901687, 38.19733166011807, -122.48087471206428, 38.26274592647846], &quot;features&quot;: [{&quot;bbox&quot;: [-122.48538151936485, 38.247201582318546, -122.48087471206428, 38.24855675680422], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.48087471206428, 38.247201582318546], [-122.48538151936485, 38.24855675680422]], &quot;type&qu

# %%
# transform_coordinate=False, noise_level="low"
gdf2.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3863bf050bdc36f42f5e6d72193cda29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3863bf050bdc36f42f5e6d72193cda29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3863bf050bdc36f42f5e6d72193cda29 = L.map(
#                 &quot;map_3863bf050bdc36f42f5e6d72193cda29&quot;,
#                 {
#                     center: [38.22973700213626, -122.51825686416443],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_3863bf050bdc36f42f5e6d72193cda29);
#
#
#
#
#
#             var tile_layer_05bb8e53da8b5b5798b8168acad87a79 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05bb8e53da8b5b5798b8168acad87a79.addTo(map_3863bf050bdc36f42f5e6d72193cda29);
#
#
#             map_3863bf050bdc36f42f5e6d72193cda29.fitBounds(
#                 [[38.197172434696085, -122.55544606669292], [38.26230156957643, -122.48106766163593]],
#                 {}
#             );
#
#
#         function geo_json_4e051b66a3327cf423ca4f2facee9893_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_4e051b66a3327cf423ca4f2facee9893_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4e051b66a3327cf423ca4f2facee9893_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_4e051b66a3327cf423ca4f2facee9893_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_4e051b66a3327cf423ca4f2facee9893_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_4e051b66a3327cf423ca4f2facee9893.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_4e051b66a3327cf423ca4f2facee9893_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_4e051b66a3327cf423ca4f2facee9893 = L.geoJson(null, {
#                 onEachFeature: geo_json_4e051b66a3327cf423ca4f2facee9893_onEachFeature,
#
#                 style: geo_json_4e051b66a3327cf423ca4f2facee9893_styler,
#                 pointToLayer: geo_json_4e051b66a3327cf423ca4f2facee9893_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_4e051b66a3327cf423ca4f2facee9893_add (data) {
#             geo_json_4e051b66a3327cf423ca4f2facee9893
#                 .addData(data);
#         }
#             geo_json_4e051b66a3327cf423ca4f2facee9893_add({&quot;bbox&quot;: [-122.55544606669292, 38.197172434696085, -122.48106766163593, 38.26230156957643], &quot;features&quot;: [{&quot;bbox&quot;: [-122.48545285921834, 38.247418108142604, -122.48106766163593, 38.24856636156973], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.48106766163593, 38.247418108142604], [-122.48545285921834, 38.24856636156973]], &quot;type&

# %%
# transform_coordinate=False, noise_level="high"
gdf2a.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c70f6240766559dd3ec4a3011e763ea7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c70f6240766559dd3ec4a3011e763ea7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c70f6240766559dd3ec4a3011e763ea7 = L.map(
#                 &quot;map_c70f6240766559dd3ec4a3011e763ea7&quot;,
#                 {
#                     center: [38.229233412749586, -122.51872654232861],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_c70f6240766559dd3ec4a3011e763ea7);
#
#
#
#
#
#             var tile_layer_d3da560ea9754795d088cef0c8dd618a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d3da560ea9754795d088cef0c8dd618a.addTo(map_c70f6240766559dd3ec4a3011e763ea7);
#
#
#             map_c70f6240766559dd3ec4a3011e763ea7.fitBounds(
#                 [[38.19683012010331, -122.55636472047382], [38.261636705395865, -122.48108836418338]],
#                 {}
#             );
#
#
#         function geo_json_63a32f085cc530465f1d8bffbb3fac4c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_63a32f085cc530465f1d8bffbb3fac4c_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_63a32f085cc530465f1d8bffbb3fac4c_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_63a32f085cc530465f1d8bffbb3fac4c_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_63a32f085cc530465f1d8bffbb3fac4c_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_63a32f085cc530465f1d8bffbb3fac4c.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_63a32f085cc530465f1d8bffbb3fac4c_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_63a32f085cc530465f1d8bffbb3fac4c = L.geoJson(null, {
#                 onEachFeature: geo_json_63a32f085cc530465f1d8bffbb3fac4c_onEachFeature,
#
#                 style: geo_json_63a32f085cc530465f1d8bffbb3fac4c_styler,
#                 pointToLayer: geo_json_63a32f085cc530465f1d8bffbb3fac4c_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_63a32f085cc530465f1d8bffbb3fac4c_add (data) {
#             geo_json_63a32f085cc530465f1d8bffbb3fac4c
#                 .addData(data);
#         }
#             geo_json_63a32f085cc530465f1d8bffbb3fac4c_add({&quot;bbox&quot;: [-122.55636472047382, 38.19683012010331, -122.48108836418338, 38.261636705395865], &quot;features&quot;: [{&quot;bbox&quot;: [-122.4850952218364, 38.24721151518238, -122.48108836418338, 38.248913868590634], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.48108836418338, 38.24721151518238], [-122.4850952218364, 38.248913868590634]], &quot;type&q

# %%
# transform_coordinate=True, noise_level="none"
gdf3.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06751d0038bfca630e8c992869b703ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06751d0038bfca630e8c992869b703ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06751d0038bfca630e8c992869b703ed = L.map(
#                 &quot;map_06751d0038bfca630e8c992869b703ed&quot;,
#                 {
#                     center: [0.019103508636253264, -0.03527685160383259],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_06751d0038bfca630e8c992869b703ed);
#
#
#
#
#
#             var tile_layer_b96c639f7dfbe3502dad59fb2a4b81c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b96c639f7dfbe3502dad59fb2a4b81c8.addTo(map_06751d0038bfca630e8c992869b703ed);
#
#
#             map_06751d0038bfca630e8c992869b703ed.fitBounds(
#                 [[-0.7026368078732839, -1.0], [0.7408438251457904, 0.9294462967923348]],
#                 {}
#             );
#
#
#         function geo_json_4599f4e5ef256014be389c589391d2fc_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_4599f4e5ef256014be389c589391d2fc_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4599f4e5ef256014be389c589391d2fc_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_4599f4e5ef256014be389c589391d2fc_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_4599f4e5ef256014be389c589391d2fc_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_4599f4e5ef256014be389c589391d2fc.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_4599f4e5ef256014be389c589391d2fc_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_4599f4e5ef256014be389c589391d2fc = L.geoJson(null, {
#                 onEachFeature: geo_json_4599f4e5ef256014be389c589391d2fc_onEachFeature,
#
#                 style: geo_json_4599f4e5ef256014be389c589391d2fc_styler,
#                 pointToLayer: geo_json_4599f4e5ef256014be389c589391d2fc_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_4599f4e5ef256014be389c589391d2fc_add (data) {
#             geo_json_4599f4e5ef256014be389c589391d2fc
#                 .addData(data);
#         }
#             geo_json_4599f4e5ef256014be389c589391d2fc_add({&quot;bbox&quot;: [-1.0, -0.7026368078732839, 0.9294462967923348, 0.7408438251457904], &quot;features&quot;: [{&quot;bbox&quot;: [-0.4736212647387142, 0.20218112694732754, -0.4688215053829895, 0.23428640924990915], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-0.4736212647387142, 0.23428640924990915], [-0.4688215053829895, 0.20218112694732754]], &quot;type&quot;: &quot;LineS

# %%
# transform_coordinate=True, noise_level="low"
gdf4.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c10156415e4dd7b3ef5023b86b6aa32 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c10156415e4dd7b3ef5023b86b6aa32&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c10156415e4dd7b3ef5023b86b6aa32 = L.map(
#                 &quot;map_9c10156415e4dd7b3ef5023b86b6aa32&quot;,
#                 {
#                     center: [0.007227690590033808, -0.039036830300826164],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_9c10156415e4dd7b3ef5023b86b6aa32);
#
#
#
#
#
#             var tile_layer_420ce2ee2cc4ad017e60296edefecc1e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_420ce2ee2cc4ad017e60296edefecc1e.addTo(map_9c10156415e4dd7b3ef5023b86b6aa32);
#
#
#             map_9c10156415e4dd7b3ef5023b86b6aa32.fitBounds(
#                 [[-0.7037513708520463, -1.0059580307522478], [0.7182067520321139, 0.9278843701505954]],
#                 {}
#             );
#
#
#         function geo_json_d69bdecbe8d1abe914ab9a146509afe9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_d69bdecbe8d1abe914ab9a146509afe9_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d69bdecbe8d1abe914ab9a146509afe9_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_d69bdecbe8d1abe914ab9a146509afe9_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d69bdecbe8d1abe914ab9a146509afe9_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_d69bdecbe8d1abe914ab9a146509afe9.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d69bdecbe8d1abe914ab9a146509afe9_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d69bdecbe8d1abe914ab9a146509afe9 = L.geoJson(null, {
#                 onEachFeature: geo_json_d69bdecbe8d1abe914ab9a146509afe9_onEachFeature,
#
#                 style: geo_json_d69bdecbe8d1abe914ab9a146509afe9_styler,
#                 pointToLayer: geo_json_d69bdecbe8d1abe914ab9a146509afe9_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_d69bdecbe8d1abe914ab9a146509afe9_add (data) {
#             geo_json_d69bdecbe8d1abe914ab9a146509afe9
#                 .addData(data);
#         }
#             geo_json_d69bdecbe8d1abe914ab9a146509afe9_add({&quot;bbox&quot;: [-1.0059580307522478, -0.7037513708520463, 0.9278843701505954, 0.7182067520321139], &quot;features&quot;: [{&quot;bbox&quot;: [-0.4675833423613453, 0.2057301245655641, -0.46720443051027544, 0.23113558943685775], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-0.46720443051027544, 0.23113558943685775], [-0.4675833423613453, 0.2057301245655641]]

# %%
# Un-reduced circuit
gdf5.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c46f6570d188334e72e2d0e023d82211 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c46f6570d188334e72e2d0e023d82211&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c46f6570d188334e72e2d0e023d82211 = L.map(
#                 &quot;map_c46f6570d188334e72e2d0e023d82211&quot;,
#                 {
#                     center: [38.229961196708544, -122.5186857132331],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_c46f6570d188334e72e2d0e023d82211);
#
#
#
#
#
#             var tile_layer_b2112f67909639a2d77341f864edd139 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b2112f67909639a2d77341f864edd139.addTo(map_c46f6570d188334e72e2d0e023d82211);
#
#
#             map_c46f6570d188334e72e2d0e023d82211.fitBounds(
#                 [[38.1971361931719, -122.55649671440192], [38.262786200245195, -122.48087471206428]],
#                 {}
#             );
#
#
#         function geo_json_016684237d757deeb159177d47d498f5_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_016684237d757deeb159177d47d498f5_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_016684237d757deeb159177d47d498f5_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_016684237d757deeb159177d47d498f5_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_016684237d757deeb159177d47d498f5_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_016684237d757deeb159177d47d498f5.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_016684237d757deeb159177d47d498f5_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_016684237d757deeb159177d47d498f5 = L.geoJson(null, {
#                 onEachFeature: geo_json_016684237d757deeb159177d47d498f5_onEachFeature,
#
#                 style: geo_json_016684237d757deeb159177d47d498f5_styler,
#                 pointToLayer: geo_json_016684237d757deeb159177d47d498f5_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_016684237d757deeb159177d47d498f5_add (data) {
#             geo_json_016684237d757deeb159177d47d498f5
#                 .addData(data);
#         }
#             geo_json_016684237d757deeb159177d47d498f5_add({&quot;bbox&quot;: [-122.55649671440192, 38.1971361931719, -122.48087471206428, 38.262786200245195], &quot;features&quot;: [{&quot;bbox&quot;: [-122.48538151936485, 38.247201582318546, -122.48087471206428, 38.24855675680422], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.48087471206428, 38.247201582318546], [-122.48538151936485, 38.24855675680422]], &quot;type&qu
